# %% [markdown]
# # Part 1 Creating and Manipulating Arrays

# %% [markdown]
# ## 1

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1.1

# %%
x = np.linspace(-2,2,100)
y = np.linspace(-2,2,100)
xx,yy = np.meshgrid(x,y)
xx,yy
# Out:
# (array([[-2.        , -1.95959596, -1.91919192, ...,  1.91919192,
#           1.95959596,  2.        ],
#         [-2.        , -1.95959596, -1.91919192, ...,  1.91919192,
#           1.95959596,  2.        ],
#         [-2.        , -1.95959596, -1.91919192, ...,  1.91919192,
#           1.95959596,  2.        ],
#         ...,
#         [-2.        , -1.95959596, -1.91919192, ...,  1.91919192,
#           1.95959596,  2.        ],
#         [-2.        , -1.95959596, -1.91919192, ...,  1.91919192,
#           1.95959596,  2.        ],
#         [-2.        , -1.95959596, -1.91919192, ...,  1.91919192,
#           1.95959596,  2.        ]]),
#  array([[-2.        , -2.        , -2.        , ..., -2.        ,
#          -2.        , -2.        ],
#         [-1.95959596, -1.95959596, -1.95959596, ..., -1.95959596,
#          -1.95959596, -1.95959596],
#         [-1.91919192, -1.91919192, -1.91919192, ..., -1.91919192,
#          -1.91919192, -1.91919192],
#         ...,
# ...

# %% [markdown]
# ## 1.2

# %%
plt.pcolormesh(xx)

# %%
plt.pcolormesh(yy)

# %% [markdown]
# ## 1.3

# %%
radial = np.sqrt(xx**2 + yy**2)
angle = np.arctan2(yy,xx)

# %% [markdown]
# ## 1.4

# %%
plt.pcolormesh(xx,yy,radial)

# %%
plt.pcolormesh(xx,yy,angle)

# %% [markdown]
# ## 1.5

# %%
f = (np.cos(4 * radial))**2 + (np.sin(4 * angle))**2
plt.pcolormesh(xx,yy,f)

# %% [markdown]
# ## 1.6

# %%
plt.plot(f.mean(axis = 1),y);

# %% [markdown]
# ## 1.7

# %%
plt.plot(x, f.mean(axis = 0));

# %% [markdown]
# # Part 2: Analyze ARGO Data

# %% [markdown]
# ## 2

# %%
date = np.load('/data9/UN3400/work/asm2296/float_data/date.npy')
T= np.load('/data9/UN3400/work/asm2296/float_data/T.npy')
S = np.load('/data9/UN3400/work/asm2296/float_data/S.npy')
P = np.load('/data9/UN3400/work/asm2296/float_data/P.npy')
levels = np.load('/data9/UN3400/work/asm2296/float_data/levels.npy')
lon = np.load('/data9/UN3400/work/asm2296/float_data/lon.npy')
lat = np.load('/data9/UN3400/work/asm2296/float_data/lat.npy')

# %% [markdown]
# ## 2.2

# %%
T.shape
# Out:
# (78, 75)

# %%
S.shape
# Out:
# (78, 75)

# %%
P.shape
# Out:
# (78, 75)

# %%
lon.shape
# Out:
# (75,)

# %%
lat.shape
# Out:
# (75,)

# %%
date.shape
# Out:
# (75,)

# %%
levels.shape
# Out:
# (78,)

# %% [markdown]
# The data covers 78 levels of depth recorded over 75 days. The ARGO Floats measure Temperature(T), Salinity(S), and Pressure(P), for each day and each level, which leads to a data frame with 78 rows and 75 columns where each day is a different column and each level is a different row. The profile has one latitude and one longitude for each day, which is why there are 75 measurements. This is also why there are 75 dates (one for each day). There are 78 levels, which is why levels have 78 entries.

# %% [markdown]
# ## 2.3

# %%
plt.plot(T,levels);
plt.ylim(80, 0)
plt.gca().xaxis.set_ticks_position("top")
plt.gca().xaxis.set_label_position("top")
plt.grid(True, c = "gray")
plt.title("Temperature vs Depth from the ARGO float")
plt.xlabel("Temperature (Celsius)")
plt.ylabel("Depth (m)")
# Out:
# Text(0, 0.5, 'Depth (m)')

# %%
plt.plot(S,levels);
plt.ylim(80, 0)
plt.gca().xaxis.set_ticks_position("top")
plt.gca().xaxis.set_label_position("top")
plt.grid(True, c = "gray")
plt.title("Salinity vs Depth from the ARGO float")
plt.xlabel("Salinity (ppt)")
plt.ylabel("Depth (m)")
# Out:
# Text(0, 0.5, 'Depth (m)')

# %%
plt.plot(P, levels);
plt.ylim(80, 0)
plt.gca().xaxis.set_ticks_position("top")
plt.gca().xaxis.set_label_position("top")
plt.grid(True, c = "gray")
plt.title("Pressure vs Depth from the ARGO float")
plt.xlabel("Pressure (psia)")
plt.ylabel("Depth (m)")
# Out:
# Text(0, 0.5, 'Depth (m)')

# %% [markdown]
# ## 2.4

# %%
T_mean = T.mean(1)
S_mean = S.mean(1)
P_mean = P.mean(1)
T_std = T.std(1)
S_std = S.std(1)
P_std = P.std(1)

# %% [markdown]
# ## 2.5

# %%
plt.plot(T_mean, levels)
plt.ylim(70, 45)
plt.errorbar(T_mean, levels, capsize=6, xerr = T_std)
plt.gca().xaxis.set_ticks_position("top")
plt.gca().xaxis.set_label_position("top")
plt.grid(True, c = "gray")
plt.title("Mean Temperature vs Depth from the ARGO float")
plt.xlabel("Mean Temperature (celsius)")
plt.ylabel("Depth (m)")
# Out:
# Text(0, 0.5, 'Depth (m)')

# %%
plt.plot(S_mean, levels)
plt.ylim(70, 45)
plt.errorbar(S_mean, levels, capsize = 6, xerr = S_std)
plt.gca().xaxis.set_ticks_position("top")
plt.gca().xaxis.set_label_position("top")
plt.grid(True, c = "gray")
plt.title("Mean Salinity vs Depth from the ARGO float")
plt.xlabel("Mean Salinity (ppt)")
plt.ylabel("Depth (m)")

# %%
plt.plot(P_mean, levels)
plt.ylim(70, 45)
plt.errorbar(P_mean, levels, capsize = 6, xerr = P_std)
plt.gca().xaxis.set_ticks_position("top")
plt.gca().xaxis.set_label_position("top")
plt.grid(True, c = "gray")
plt.title("Mean Pressure vs Depth from the ARGO float")
plt.xlabel("Mean Pressure (psia)")
plt.ylabel("Depth (m)")
# Out:
# Text(0, 0.5, 'Depth (m)')

# %% [markdown]
# ## 2.6

# %%
T_nanmean = np.nanmean(T, axis = 1)
S_nanmean = np.nanmean(S, axis = 1)
P_nanmean = np.nanmean(P, axis = 1)
T_nanstd = np.nanstd(T, axis = 1)
S_nanstd = np.nanstd(S, axis = 1)
P_nanstd = np.nanstd(P, axis = 1)

# %%
plt.plot(T_nanmean, levels)
plt.ylim(80, 0)
plt.errorbar(T_nanmean, levels, capsize = 2, xerr = T_nanstd)
plt.gca().xaxis.set_ticks_position("top")
plt.gca().xaxis.set_label_position("top")
plt.grid(True, c = "gray")
plt.title("Mean Temperature vs Depth from the ARGO float")
plt.xlabel("Mean Temperature (celsius)")
plt.ylabel("Depth (m)")

# %%
plt.plot(S_nanmean, levels)
plt.ylim(80, 0)
plt.errorbar(S_nanmean, levels, capsize = 2, xerr = S_nanstd)
plt.gca().xaxis.set_ticks_position("top")
plt.gca().xaxis.set_label_position("top")
plt.grid(True, c = "gray")
plt.title("Mean Salinity vs Depth from the ARGO float")
plt.xlabel("Mean Salinity (ppt)")
plt.ylabel("Depth (m)")

# %%
plt.plot(P_nanmean, levels)
plt.ylim(80, 0)
plt.errorbar(P_nanmean, levels, capsize = 2, xerr = P_nanstd)
plt.gca().xaxis.set_ticks_position("top")
plt.gca().xaxis.set_label_position("top")
plt.grid(True, c = "gray")
plt.title("Mean Pressure vs Depth from the ARGO float")
plt.xlabel("Mean Pressure (psia)")
plt.ylabel("Depth (m)")
# Out:
# Text(0, 0.5, 'Depth (m)')

# %% [markdown]
# ## 2.7

# %%
plt.scatter(lon,lat, c = date)
plt.grid(True, c = "black")
plt.colorbar(label = "Date")
plt.gca().xaxis.set_ticks_position("top")
plt.gca().xaxis.set_label_position("top")
plt.title("Position of the ARGO float over time")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')
